# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
import pandas as pd
import src.data_processing as dp
import matplotlib.pyplot as plt

# %%
ticker = 'ES'
mois = "Aug2017"
type_market = "Calm"
ticks_datas = dp.data_loader(f"../data", ticker, "05")

# %%
len(ticks_datas)

# %%
ticks_datas.iloc[:5]

# %%
rolling, ticks_datas = dp.data_cleaner_for_bars(ticks_datas)

# %%
len(ticks_datas)

# %%
ticks_bar = bc.tick_bars_creator(ticks_datas)
ticks_bar.head()

# %%
len(ticks_bar)

# %%
temp = bc.dollar_runs_bar_creator(ticks_datas)
temp1 = bc.dollar_imbalance_bar_creator(ticks_datas)

# %%
temp.head(10)

# %%
temp1.head(10)

# %%
temp.iloc[-100:]

# %%
len(temp1)

# %%
plt.figure(figsize=(15, 10))
temp1['close'].plot()

# %%
ticks_datas

# %%
plt.figure(figsize=(15, 10))
# ticks_datas[ticks_datas['ts_event'].between('2022-01-01', '2022-01-31')]['price'].plot()
ticks_datas['price'].plot()
