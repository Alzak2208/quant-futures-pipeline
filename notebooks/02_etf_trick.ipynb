# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
import numpy as np
import src.data_processing as dp
from src.etf_trick import ETFTrick
from src.instrument_config import FUTURE_SPECS

# %%
rolling_dates, etf_data = dp.multi_assets_synchro_multi(["ES", "NQ", "YM", "CL", "RB"])

# %%
etf_data.head()

# %%
etf_trick = ETFTrick(FUTURE_SPECS)

# %%
etf_trick = etf_trick.run(etf_data, 
                          rolling_dict=rolling_dates, 
                          weights=np.array([1/5] * 5, dtype=np.float64))

# %%
etf_trick.h

# %%
etf_trick.h.iloc[:10]
